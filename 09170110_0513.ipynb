# %%
# !sudo apt install tesseract-ocr
# !apt install libtesseract-dev
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 34 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# ...

# %%
import pytesseract
import shutil
import os
import random
try:
  from PIL import Image
except ImportError:
  import Image

# %%
text = pytesseract.image_to_string(Image.open('rbt1388.jpg'))
print(text)
# Out:
# RBT-1388

# %%
text = pytesseract.image_to_string(Image.open('chi_sim.jpg'),lang="chi_tra")
print(text)
# Out:
# 怠 第 200 期
# 2011 年 第 2 期
#
# 航 船 曰 子 工 程
# Ship Plectronic Engineering
#
#
#
# 基 于 Python 的 ABAQUS 二 次 升 爰 方 法 与 皮 用 ﹣
#
# 張 ﹣ 張
#
# 与 永2)
# ( 海 牢 芳 那 州 地 匡 宛 事 代 表 室 ，
# ( 中 國 船 船 重 工 集 困 公 司 第 七 一 三 研 究 所 ˋ
#
# 李 四 超 0
# 郡 州 450015﹚
# 郝 州 450015﹚
#
# 摘 ﹣ 要 ABAQUS 加 二 次 井 炕 用 戶 提 供 了 Python 胖 本 援 口 。 在 ABAQUS 珈 境 下 拭 行 Python 腳 本 ， 可 方 便 地 宏 現 自
# 劫 化 刨 建 ﹒ 重 复 ﹒ 修 改 模 型 及 分 析 任 功 ， 宏 現 參 敷 化 研 究 ， 近 同 結 果 數 据 庠 等 功 能 。 以 某 支 架 力 例 ， 介 累 了 基 于 Python 的
#
# ABAQUS 二 次 升 炔 原 理 丐 方 法 。
#
# 美 謾 冷 ABAQUS﹩ Python 腳 本 ﹔ 二 次 升 炔 ﹔ 結 果 敷 据 庠 ﹔ 參 敷 化 研 究
#
# 甾 圉 分 羡 旱 TP311
#
# Method and Application of Second﹣developed ABAQUS Based on Python
#
# Zhang OQiang
#
# Ma Yong﹕﹀
#
# L3 Sichao
#
# (Nilitary Representatives (fiee of Navy in Zhengzhou，Zhengzhou 4500155
# (No﹒713 Research Institute of CSIC﹖”，Zhengzhou 450015
#
# Abstract The Python Script Interface is provided by ABAUUQS for progranmners aimed at second﹣developed ABAQUS﹒
# ...

# %%
import numpy as np
from PIL import Image
import jieba
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
from wordcloud import WordCloud
with open("text17_33_2.txt") as fp:
  txt=fp.read()
cut_text=' '.join(jieba.cut(txt))
bgimage= np.array(Image.open("star.gif"))
wd=WordCloud(font_path=font,background_color="white",mask=bgimage).generate(txt)
plt.imshow(wd)
plt.axis("off")
plt.show()

# %%
print(pytesseract.get_languages(config=''))
# Out:
# ['eng', 'osd', 'chi_tra']

# %%
# !pip install wordcloud

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS

# %%
from wordcloud import WordCloud
with open("text17_28.txt") as fp:
  txt=fp.read()
wd=WordCloud().generate(txt)
wd.to_image().save("1.jpg")
from google.colab.patches import cv2,cv2_imshow
image=cv2.imread("1.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FA1F4900C10>

# %%
from wordcloud import WordCloud
with open("text17_29_3.txt") as fp:
  txt=fp.read()
font ='SourceHanSansTW-Regular.otf'
wd=WordCloud(font_path=font).generate(txt)
wd.to_image().save("2.jpg")
from google.colab.patches import cv2,cv2_imshow
image=cv2.imread("2.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FA1F4915E10>
